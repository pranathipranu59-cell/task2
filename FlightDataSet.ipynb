# %% [markdown]
# <a href="https://colab.research.google.com/github/pranathipranu59-cell/task2/blob/main/FlightDataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-24770da9-b1cf-4dfa-b487-54854293c4b2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24770da9-b1cf-4dfa-b487-54854293c4b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('flights_dataset.csv')
df.head()
# Out:
#   Flight_ID   Airline Origin Destination  Scheduled_Departure  \
# 0     F0001  AirIndia    BLR         HYD  2023-05-29 04:10:00
# 1     F0002   Vistara    BOM         BLR  2023-05-05 18:15:00
# 2     F0003  AirIndia    HYD         BLR  2023-05-21 06:37:00
# 3     F0004  SpiceJet    CCU         HYD  2023-05-04 08:02:00
# 4     F0005   Vistara    DEL         BLR  2023-05-01 22:57:00
#
#       Actual_Departure  Distance  Delayed
# 0  2023-05-29 04:20:00       428        0
# 1  2023-05-05 18:25:00       631        0
# 2  2023-05-21 06:42:00      1521        0
# 3  2023-05-04 08:07:00       677        0
# 4  2023-05-01 23:27:00      1582        1

# %%
#Number of Flights by Airlines
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Airline', order=df['Airline'].value_counts().index)
plt.title('Number of Flights by Airline')
plt.xlabel('Airline')
plt.ylabel('Flight Count')
plt.show()

#Number of Delayed vs. On-time Flights per Airline
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Airline', hue='Delayed')
plt.title('Number of Delayed vs. On-time Flights per Airline')
plt.xlabel('Airline')
plt.ylabel('Count')
plt.legend(['On-time','Delayed'])
plt.show()

#Average Flight Distance by Airline
plt.figure(figsize=(8,5))
sns.barplot(data=df, x='Airline', y='Distance', estimator='mean', ci=None)
plt.title('Average Flight Distance by Airline')
plt.xlabel('Airline')
plt.ylabel('Average Distance')
plt.show()

#Delay Rate by Origin Airport
delay_rate = df.groupby('Origin')['Delayed'].mean().reset_index()
plt.figure(figsize=(12,5))
sns.barplot(data=delay_rate, x='Origin', y='Delayed')
plt.title('Delay Rate by Origin Airport')
plt.xlabel('Origin Airport')
plt.ylabel('Delay Rate')
plt.show()

#Distribution of Flight Distances
#Number of Flights per Day
sns.histplot(data=df, x='Distance', kde=True)
plt.title('Distribution of Flight Distances')
plt.xlabel('Distance (km)')
plt.ylabel('Number of Flights')
plt.show()

df['Scheduled_Departure'] = pd.to_datetime(df['Scheduled_Departure'])
df['Actual_Departure'] = pd.to_datetime(df['Actual_Departure'])

# Example: Flights per day
df['FlightDay'] = df['Scheduled_Departure'].dt.date
sns.histplot(df['FlightDay'], bins=30)
plt.title('Number of Flights per Day')
plt.xticks(rotation=45)
plt.show()

# Select only numeric columns
corr = df.select_dtypes(include=['float64', 'int64']).corr()
sns.heatmap(corr, annot=True)
plt.title('Numerical Feature Correlations')
plt.show()

df['Scheduled_Departure'] = pd.to_datetime(df['Scheduled_Departure'])
plt.figure(figsize=(10, 6))
sns.boxplot(x='Airline', y='Distance', data=df)
plt.title("Flight Distance Distributions by Airline")
plt.ylabel("Distance (km)")
plt.xlabel("Airline")
plt.show()

# Extract hour from the Scheduled_Departure column
df['Hour'] = df['Scheduled_Departure'].dt.hour

plt.figure(figsize=(12, 6))
sns.countplot(x='Hour', hue='Delayed', data=df)
plt.title("Delay Patterns by Hour of Scheduled Departure")
plt.xlabel("Hour of Scheduled Departure")
plt.ylabel("Number of Flights")
plt.legend(title='Delayed', labels=['No', 'Yes'])
plt.show()
# Out:
# /tmp/ipython-input-4208269907.py:20: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Airline', y='Distance', estimator='mean', ci=None)
